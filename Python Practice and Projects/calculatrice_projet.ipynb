# %%
while True:
    
    try:
        user_input1 = input("Enter your first number or 'stop' when you wish to stop: ")         # these lines ask the inputs from the user
        if user_input1.lower() == "stop":    
            user_final_input = input("What next? ") 
            if user_final_input.lower() == "file":     # Takes the file name from the user
                
                while True : 
                    user_input_filename= input("Enter the file name please:")
                         
                    try:                                    # using the try and except statements to handle the file name error

                        with open(user_input_filename, 'r') as f:
                            data = f.readlines()
                            data = data[0:]
                            for o in data:
                                print(o.strip())

                            break
                
                

                    except FileNotFoundError:
                        print("Oops the file you are trying to open doesn't exist, please try to enter table")
                
                break 
                    #finally:
                        #close(Eq_file)
                        #break
            elif user_final_input.lower() == "back":
                    continue 


            

        user_input2 = input("Operator: ") 
        user_input3 = input("second number: ")
        a = int(user_input1)
        b = int(user_input3)
      
          
        Eq_file = open("Table.txt","a")        # create an empty file with a relative directory 


        if user_input2 == "+":              # and these if and else statement check if the operator entered by the user
            Eq1 = (f"{a} + {b} =  {a+b}")
            Eq_file.write(Eq1 + '\n')
            print(Eq1)
        elif user_input2 =="-":
            Eq2 = (f"{a} - {b} = {a-b}")
            Eq_file.write(Eq2 + '\n')
            print(Eq2)

        elif user_input2 == "x":
            Eq3 = (f"{a} x {b} = {a*b}")
            Eq_file.write(Eq3 + '\n')
            print(Eq3)
        elif user_input2 == "/":
            Eq4 = (f"{a} / {b} =  {a/b}")
            Eq_file.write(Eq4 + '\n')
            print(Eq4)
        elif user_input2 == "%":
            Eq5 = (f"{a} % {b} =  {a%b}")
            Eq_file.write(Eq5 + '\n')
            print(Eq5)
        else:
            print("Oops you need to enter the right operator")

        Eq_file = open("Table.txt","r")            # this instruction open the text file for reading
        
        
        
        
 
    
    except ValueError:                  # this exception will rase an error and redirect the user to the beginning of the loop if any error occurs whether it's a letter instead of a number or a wrong operator
            print("Oops enter numbers please")
    except ZeroDivisionError:
            print("Oops can't divide by zero, try an other number")
# Out:
# Enter your first number or 'stop' when you wish to stop: stop
# What next? file
# Enter the file name please:table
# Oops the file you are trying to open doesn't exist, please try to enter table
# Enter the file name please:Table.txt
# 56 / 6 =  9.33333333333333435 - 12 = 2325 + 12 =  3745 - 25 = 20
# 56 + 10 =  66
# 56 + 4 =  60
# 45 / 5 =  9.0
# 34 + 6 =  40
# 25 / 5 =  5.0
# 34 + 6 =  40
# 35 + 5 =  40
# 67 + 56 =  123
# 67 / 3 =  22.333333333333332
# 78 - 18 = 60
# 25 / 5 =  5.0
# 25 - 5 = 20
# 25 / 5 =  5.0
# 67 - 17 = 50
# 45 / 5 =  9.0
# 45 / 5 =  9.0
# 67 - 17 = 50
# 45 / 9 =  5.0
# 56 / 6 =  9.333333333333334
# 24 / 3 =  8.0
# 45 / 6 =  7.5
# 35 + 35 =  70
# 45 / 7 =  6.428571428571429
# 8 x 6 = 48
# 35 / 5 =  7.0
# 35 x 4 = 140
# 34 - 24 = 10
# 34 / 7 =  4.857142857142857
# 34 + 23 =  57
# 23 + 7 =  30
# 34 + 6 =  40
# 45 + 15 =  60
# 0 + 6 =  6
